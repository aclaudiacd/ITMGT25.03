# %%
pip install requests matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import time
import matplotlib.pyplot as plt

api_endpoint = "http://api.open-notify.org/iss-now.json"

data_points = []  # Initialize the data_points list

for i in range(100):
    response = requests.get(api_endpoint)
    if response.status_code == 200:
        data = response.json()
        timestamp = data['timestamp']
        latitude = data['iss_position']['latitude']
        longitude = data['iss_position']['longitude']
        data_points.append({'timestamp': timestamp, 'latitude': latitude, 'longitude': longitude})
        print(f"Data point {i+1} collected.")
    else:
        print(f"Error: Request {i+1} failed.")
    time.sleep(10)
# Out:
# Data point 1 collected.
# Data point 2 collected.
# Data point 3 collected.
# Data point 4 collected.
# Data point 5 collected.
# Data point 6 collected.
# Data point 7 collected.
# Data point 8 collected.
# Data point 9 collected.
# Data point 10 collected.
# Data point 11 collected.
# Data point 12 collected.
# Data point 13 collected.
# Data point 14 collected.
# Data point 15 collected.
# Data point 16 collected.
# Data point 17 collected.
# Data point 18 collected.
# Data point 19 collected.
# Data point 20 collected.
# Data point 21 collected.
# Data point 22 collected.
# Data point 23 collected.
# Data point 24 collected.
# Data point 25 collected.
# Data point 26 collected.
# Data point 27 collected.
# Data point 28 collected.
# Data point 29 collected.
# Data point 30 collected.
# Data point 31 collected.
# Data point 32 collected.
# Data point 33 collected.
# Data point 34 collected.
# Data point 35 collected.
# Data point 36 collected.
# Data point 37 collected.
# ...

# %%
latitude_values = [data_point['latitude'] for data_point in data_points]
longitude_values = [data_point['longitude'] for data_point in data_points]

# %%
plt.plot(longitude_values, latitude_values)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Path of the International Space Station')
plt.grid(True)
plt.show()
